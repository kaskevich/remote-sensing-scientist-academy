# %% [markdown]
# # UAV and Satellite Analysis Pipeline
#
# **Learner:** Add your name or researcher identifier
# **Module:** Geospatial Data Science
# **Study system:** Baltic coastal meadows

# %% [markdown]
# ## Spatial contract
#
# Before every operation, record the observation unit, spatial support, CRS, extent, resolution, time and primary uncertainty.

# %%
from pathlib import Path

PROJECT = Path.cwd()
DATA = PROJECT / "data"
OUTPUTS = PROJECT / "outputs"
OUTPUTS.mkdir(exist_ok=True)
print(f"Project: {PROJECT}")

# %% [markdown]
# ## Input inventory
#
# Record the source, stable identifier, licence, file checksum and spatial metadata for every field, vector, UAV and satellite input. Do not add private credentials to this notebook.

# %%
input_inventory = []
quality_decisions = []
portfolio_artifacts = []
print("Pipeline records initialised")

# %% [markdown]
# ## Lesson 2.1 checkpoint — spatial evidence inventory
#
# Classify each handover asset as tabular, vector, raster or spatial with incomplete reference metadata. Record observation unit, location evidence, spatial model, CRS evidence, limitation and next action.

# %% [markdown]
# ## Lesson 2.2 checkpoint — CRS transformation audit
#
# Record source and target CRS, units, area of use, bounds and sample coordinates. Explain whether each operation assigns trusted metadata or transforms coordinates, and preserve an independent location check.

# %% [markdown]
# ## Lesson 2.3 checkpoint — spatial support decision
#
# Compare field-quadrat, UAV-pixel and satellite-pixel support. State the aggregation rule, timing constraint, registration risk, ecological rationale and remaining mismatch.

# %% [markdown]
# ## Lesson 2.4 checkpoint — format and metadata register
#
# Choose formats from data structure, scale, access pattern and interoperability. Record one limitation, one rejected alternative and the post-conversion QA evidence for each deliverable.

# %% [markdown]
# ## Chapter 1 Practicum checkpoint — geospatial data acceptance decision
#
# Link `DATA_ACCEPTANCE_DECISION.md`. For each asset retain the stated use, evidence, accept/review/reject decision, remaining uncertainty, owner and next action.

# %% [markdown]
# ## Lesson 2.5 checkpoint — vector spatial audit
#
# Audit feature counts, stable identifiers, geometry types, missing and empty geometry, validity, CRS and bounds before analysis. Preserve raw inputs and verify every GeoPackage derivative after reopening it.

# %% [markdown]
# ## Lesson 2.6 checkpoint — geometry and support decision
#
# Record predicate or geometry operation, projected units, parameters, before-and-after geometry evidence and the independent scientific rationale for the selected analytical support.

# %% [markdown]
# ## Lesson 2.7 checkpoint — spatial assignment audit
#
# For every attribute join, spatial join, nearest relationship or overlay, record predicate, join type, expected cardinality, input and output counts, unmatched and repeated IDs, distance or area evidence and unresolved cases.

# %% [markdown]
# ## Lesson 2.8 checkpoint — verified spatial-index profile
#
# Compare naive and indexed searches with the same exact predicate. Record all possible pairs, bounding-box candidates, exact matches, repeated timings, environment versions and stable-ID equivalence before interpreting performance.

# %% [markdown]
# ## Lesson 2.9 checkpoint — vector topology decision log
#
# Diagnose missing, empty, invalid, multipart, duplicate and coverage conditions separately. Preserve immutable sources, audit every repair or aggregation candidate and retain accepted, rejected and unresolved decisions.

# %% [markdown]
# ## Lesson 2.10 checkpoint — QGIS visual verification package
#
# Record QGIS version, project and layer CRS, source paths, numerical reconciliation, diagnostic styling, validity and join checks, structured observations and verified PDF/PNG exports. Return confirmed issues to the reproducible pipeline.

# %% [markdown]
# ## Chapter 2 Practicum checkpoint — vector handover review
#
# Link the notebook, reopened GeoPackage, integrity report, QA map and handover note. Record whether the package is accepted, conditionally accepted or rejected for the defined analysis.

# %% [markdown]
# ## Lesson 2.11 checkpoint — raster anatomy record
#
# Document array shape, bands, transform, CRS, resolution, bounds, data type, NoData, mask, units and measurement semantics. Distinguish the cell edge, centre and footprint.

# %% [markdown]
# ## Lesson 2.12 checkpoint — Rasterio round-trip audit
#
# Inspect metadata before reading values, calculate valid-only diagnostics, write to a new path, reopen the derivative and compare values, mask, grid, data type and declared metadata.

# %% [markdown]
# ## Lesson 2.13 checkpoint — raster transformation decision log
#
# Record whether each operation crops, masks, reprojects or resamples; define the target grid and justify the resampling rule separately for continuous and categorical variables.

# %% [markdown]
# ## Lesson 2.14 checkpoint — grid-integrity contract
#
# Assert CRS, transform, dimensions, bounds, pixel orientation and NoData policy before any cell-wise calculation. Log each mismatch and its resolution.

# %% [markdown]
# ## Lesson 2.15 checkpoint — raster–vector support record
#
# For point and polygon extraction, preserve stable IDs, coordinate and boundary rules, valid-cell counts, summary statistic, units and the measurement-support limitation.

# %% [markdown]
# ## Lesson 2.16 checkpoint — windowed-processing equivalence
#
# Estimate memory, process native blocks, preserve window transforms and masks, and compare a small windowed result with the trusted full-array calculation.

# %% [markdown]
# ## Lesson 2.17 checkpoint — terrain derivative audit
#
# Record surface meaning, horizontal and vertical units, vertical-reference status, derivative formulas, slope units, aspect convention, hillshade parameters, edge treatment and plausible ranges.

# %% [markdown]
# ## Chapter 3 Practicum checkpoint — analysis-ready raster stack
#
# Link the inventory, target-grid contract, transformation log, five aligned outputs, extraction tables, checksums and QA report. State whether the stack is accepted, conditionally accepted or rejected for the defined analysis.

# %% [markdown]
# ## Lesson 2.18 checkpoint — UAV sensor and product inventory
#
# Separate platform, payload, navigation and direct image records from point clouds, surfaces, orthorectified imagery, mosaics, reflectance products and indices. Record nominal GSD and acquisition interval without calling either accuracy or simultaneity.

# %% [markdown]
# ## Lesson 2.19 checkpoint — mission-design sheet
#
# Record sensor dimensions, focal length, height above ground, nominal GSD, footprint, forward/side spacing, speed, trigger interval, shutter, terrain assumptions and achieved-coverage evidence.

# %% [markdown]
# ## Lesson 2.20 checkpoint — radiometric quality audit
#
# Track stored quantity, scale, units, exposure, saturation, panels, irradiance, vignetting, illumination gradients and band co-registration. Keep unresolved scale as a blocking decision.

# %% [markdown]
# ## Lesson 2.21 checkpoint — georeferencing accuracy report
#
# Keep control and withheld check points separate. Report signed bias, component and planimetric RMSE, maximum, residual vectors, horizontal/vertical reference and local weak regions.

# %% [markdown]
# ## Lesson 2.22 checkpoint — photogrammetric reconstruction audit
#
# Map perspective images through features, matches, tie points, camera estimation, bundle adjustment, sparse/dense clouds, a surface, orthorectification and mosaicking. Label reprojection error as internal evidence.

# %% [markdown]
# ## Lesson 2.23 checkpoint — UAV product interpretation
#
# Distinguish point clouds, DSM, DTM, conditional surface differences and orthomosaics. Locate seamlines, ghosting, spikes, pits, occlusion, interpolation and edge limitations.

# %% [markdown]
# ## Lesson 2.24 checkpoint — UAV QA matrix
#
# For mission, image, reconstruction, georeferencing, mosaic, DSM, multispectral and temporal QA, record expected, observed, status, severity, scientific consequence, action, evidence and owner.

# %% [markdown]
# ## Lesson 2.25 checkpoint — analysis-ready UAV multispectral stack
#
# Validate identity, scale, radiometry, grid and masks before safe NDVI/GNDVI. Record accepted and blocked layers, DSM limits, plot support and reopened-output checks in the stack manifest.

# %% [markdown]
# ## Chapter 4 Practicum checkpoint — professional UAV survey assessment
#
# Link the mission, georeferencing, radiometric, alignment, QA, stack and extraction tables with the QA map and final product/region decisions. Preserve every deliberate defect and corrective action.

# %% [markdown]
# ## Lesson 2.26 checkpoint — optical observation contract
#
# Record the observation chain, product level, scale and offset, band identity, native support, acquisition time, cloud/shadow policy and accept/review/reject decision.

# %% [markdown]
# ## Lesson 2.27 checkpoint — spectral-index evidence
#
# Keep input reflectance, joint masks, formula, parameters, native support, denominator rule and proxy limitations beside every NDVI, GNDVI, SAVI or MSAVI value.

# %% [markdown]
# ## Lesson 2.28 checkpoint — SAR comparability
#
# Record mode, polarisation, orbit, relative orbit, incidence angle, calibration quantity, terrain correction, linear/decibel representation and competing physical explanations.

# %% [markdown]
# ## Lesson 2.29 checkpoint — imaging-spectroscopy feature note
#
# Preserve wavelength units, band centres, bandwidths, bad-band and SNR decisions, feature definition, mixed-pixel limits and leakage-safe validation design.

# %% [markdown]
# ## Lesson 2.30 checkpoint — LiDAR structural evidence
#
# Trace returns through classification, point support, vertical reference, DTM/DSM construction, aligned surface difference, negative-height QA and ecological limits.

# %% [markdown]
# ## Chapter 5 Practicum checkpoint — satellite EO evidence package
#
# Link optical, index, SAR, spectral and structural QA without erasing sensor-specific support. Record convergence, divergence, blocked claims and the evidence required for validation.

# %% [markdown]
# ## Lesson 2.31 checkpoint — spatial autocorrelation
#
# Record the analysis set, neighbour hypothesis, weights transformation, islands, edge conditions, permutation seed, global statistic and sensitivity before interpreting spatial pattern.

# %% [markdown]
# ## Lesson 2.32 checkpoint — spatial sampling design
#
# Separate the target population, operational frame, selection design, realised observations and QA analysis set. Preserve inclusion evidence, access restrictions and replacement rules.

# %% [markdown]
# ## Lesson 2.33 checkpoint — geostatistical interpolation
#
# Keep the continuity assumption, empirical variogram, alternative parameters, separated spatial holdouts, prediction residuals, model uncertainty and extrapolation mask together.

# %% [markdown]
# ## Lesson 2.34 checkpoint — spatial regression diagnosis
#
# Preserve the ordinary baseline, mapped residuals, spatial-weights sensitivity, process hypothesis, candidate model and geographically separated validation evidence.

# %% [markdown]
# ## Chapter 6 Practicum checkpoint — spatial inference and validation
#
# Deliver the sampling audit, weights sensitivity, interpolation validation, residual diagnostics, support-aware map and a bounded accept, review or block release decision.

# %% [markdown]
# ## Lesson 2.35 checkpoint — SQL population and joins
#
# Record table grain, keys, join cardinality, filters, NULL policy, source/intermediate/result counts and the exact scientific population declared by each released query.

# %% [markdown]
# ## Lesson 2.36 checkpoint — PostGIS spatial semantics
#
# Preserve geometry type, SRID, predicate and distance meaning, boundary cases, candidate counts, index evidence and stable-pair reconciliation with the equivalent GeoPandas operation.

# %% [markdown]
# ## Lesson 2.37 checkpoint — governed spatial storage
#
# Map authoritative sources, immutable objects, access copies and derivatives to GeoPackage, GeoParquet, PostGIS or object storage with owners, lineage, roles, recovery and measurable scaling triggers.

# %% [markdown]
# ## Chapter 7 Practicum checkpoint — spatial database and governance
#
# Deliver the authority register, reconciled imports, relational and spatial query packs, predicate audit, architecture matrix, access and recovery controls, and an implement, conditional or blocked handover decision.

# %% [markdown]
# ## Lesson 2.38 checkpoint — labelled arrays and spatial metadata
#
# Record dimensions, coordinate labels and direction, CRS, transform, units, scale, nodata and exact-alignment evidence before interpreting an Xarray or Rioxarray result.

# %% [markdown]
# ## Lesson 2.39 checkpoint — EO cube comparability
#
# Preserve the measurement, grid, time, scaling, mask and provenance contract; publish every seasonal statistic with valid-observation counts and contributing source IDs.

# %% [markdown]
# ## Lesson 2.40 checkpoint — bounded lazy computation
#
# Estimate logical and chunk memory, align chunks with storage and query shape, select before compute, set abort criteria and compare the bounded lazy result with a trusted eager result.

# %% [markdown]
# ## Lesson 2.41 checkpoint — cloud-format evidence
#
# Separate COG and Zarr claims from verified layout, service, client, version, codec, request-pattern and result evidence; publish immutable validated versions.

# %% [markdown]
# ## Lesson 2.42 checkpoint — reproducible STAC discovery
#
# Preserve endpoint or fixture, conformance, Collection, geometry, interval, filters, pagination, Item IDs, asset roles, licences and cube-eligibility decisions without signed URLs.

# %% [markdown]
# ## Chapter 8 Practicum checkpoint — cloud-native EO evidence cube
#
# Deliver the deterministic Item–asset inventory, cube contract, labelled diagnostic, valid counts, chunk budget, COG/Zarr audit, pipeline reconciliation and a release, conditional or blocked decision.

# %% [markdown]
# ## Working rule for later chapters
#
# Extend this notebook or linked project files after every lesson. Keep raw data unchanged. Store derived products under `outputs/` and explain every exclusion, transformation, resampling and validation decision.

# %% [markdown]
# ## Capstone release checklist
#
# - [ ] Inputs and provenance validated
# - [ ] CRS, grid and spatial support documented
# - [ ] UAV and satellite QA complete
# - [ ] Field extraction and spatial validation complete
# - [ ] Maps, tables, uncertainty and limitations communicated
# - [ ] Environment, tests and release instructions included
